# %% [markdown]
# <a href="https://colab.research.google.com/github/vineetsoni145/Information-Security/blob/main/Practical3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install pycryptodome
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 14.8 MB/s eta 0:00:00

# %%
from Crypto import Cipher
from Crypto.Cipher import AES
from Crypto.Random import get_random_bytes
from Crypto.Util.Padding import pad, unpad

plaintext = input("Enter the message to encrypt:")
data = plaintext.encode('utf-8')

key = get_random_bytes(16)

cipher = AES.new(key, AES.MODE_CBC)

iv = cipher.iv
ciphertext = cipher.encrypt(pad(data, AES.block_size))

print("\n========== Encryption ==========")
print("Original Plaintext :", plaintext)
print("Secret Key (Hex) :", key.hex())
print("Initialization IV :", iv.hex())
print("Cipher Text (Hex) :", ciphertext.hex())

decrypt_cipher = AES.new(key, AES.MODE_CBC, iv)
decrypted_data = unpad(
    decrypt_cipher.decrypt(ciphertext),
    AES.block_size
    )
decrypted_text = decrypted_data.decode('utf-8')

print("\n========== Decryption ==========")
print("Decrypted Text :", decrypted_text)

if plaintext == decrypted_text:
  print("\nResult: Encryption and Decryption Successful.")
else:
  print("\nResult: Encryption and Decryption Failed.")
# Out:
# Enter the message to encrypt:vineet
#
# ========== Encryption ==========
# Original Plaintext : vineet
# Secret Key (Hex) : 5b224b9441db999c639873ce32522250
# Initialization IV : fa9bf2f32a66369b49044815f28aecb0
# Cipher Text (Hex) : be77d716c45997b54d6f70cf437da6f7
#
# ========== Decryption ==========
# Decrypted Text : vineet
#
# Result: Encryption and Decryption Successful.
