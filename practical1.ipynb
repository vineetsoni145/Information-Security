# %% [markdown]
# <a href="https://colab.research.google.com/github/vineetsoni145/Information-Security/blob/main/practical1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import socket
import platform
import requests
from datetime import datetime

print("-"*70)
print("CYBERSECURITY ENVIRONMENT SETUP USING GOOGLE COLAB")
print("="*70)
print("\nCURRENT DATE AND TIME")
print("-"*70)
current_time = datetime.now()
print("Current Date and Time:",current_time)
print("\nSYSTEM INFORMATION")
print("-"*70)

print("Operating System: ", platform.system())
print("System Release: ", platform.release())
print("Machine Type: ", platform.machine())
print("Processor: ", platform.processor())
print("\nHOST INFORMATION")
print("-"*70)

hostname = socket.gethostname()

print("Hostname: ", hostname)

try:
  ip_address = socket.gethostbyname(hostname)
  print("IP Address: ", ip_address)
except :
  print("Unable to Retrieve IP Address")

print("\nINTERNET CONNECTIVITY TEST")
print("-"*70)

try:
  response = requests.get("https://github.com/PANARA195/3040233402_Information-Security/blob/main/IS_PRACTICAL_1.pdf")

  print("Connection Status : SUCCESS")
  print("HTTP Status Code : ", response.status_code)

except:
  print("Connection Status : Failed")

print("\nDNS RESOLUTION TEST")
print("-"*70)

try:
  github_ip - socket.gethostbyname("https://github.com/PANARA195/3040233402_Information-Security/blob/main/IS_PRACTICAL_1.pdf")

  print("Domain Name : github.com")
  print("Resolved IP :", github_ip)

except:
  print("DNS Resolution Failed")

print("\nPORT CONNECTIVITY TEST")
print("-"*70)

host = "google.com"

ports = [80, 443]

for port in ports:
  try:
    connection = socket.create_connection((host,port), timeout=5)
    print(f"Port {port} is open")
    connection.close()
  except:
    print(f"Port {port} is closed")

print("\nWEBSITE SECURITY CHECK")
print("-"*70)

url = "https://github.com/PANARA195/3040233402_Information-Security/blob/main/IS_PRACTICAL_1.pdf"

if url.startswith("https://"):
  print("Secure HTTPS Protocol Detected")
else :
  print("Insecure Protocol")

print("\nCYBERSECURITY ENVIROMENT STATUS")
print("-"*70)

print("Python Environment Ready")
print("Internet Connectivity Verified")
print("DNS Resolution Working")
print("Port Connectivity Verified")
print("Website Security Verified")
print("Security Enviroment Ready")

print("\nPractical Completed Successfully")

print("-"*70)
# Out:
# ----------------------------------------------------------------------
# CYBERSECURITY ENVIRONMENT SETUP USING GOOGLE COLAB
# ...
#
# CURRENT DATE AND TIME
# ----------------------------------------------------------------------
# Current Date and Time: 2026-07-13 08:20:20.173174
#
# SYSTEM INFORMATION
# ----------------------------------------------------------------------
# Operating System:  Linux
# System Release:  6.6.122+
# Machine Type:  x86_64
# Processor:  x86_64
#
# HOST INFORMATION
# ----------------------------------------------------------------------
# Hostname:  8a2dc28f9ae6
# IP Address:  172.28.0.12
#
# INTERNET CONNECTIVITY TEST
# ----------------------------------------------------------------------
# Connection Status : SUCCESS
# HTTP Status Code :  200
#
# DNS RESOLUTION TEST
# ----------------------------------------------------------------------
# DNS Resolution Failed
#
# PORT CONNECTIVITY TEST
# ...
